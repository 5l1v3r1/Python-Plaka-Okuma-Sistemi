# %% [markdown]
# #  2018 yılında geçen araçlar

# %%
import pandas as pd

yol='C:\\Users\\mertoglue\\AnacondaProjects\\CSV\\plakaOlustur\\giden.csv'
        
veri = pd.read_csv(yol, encoding = "ISO-8859-1" ,sep=',')   # pandas ile dosya okunup veriler alınıyor ve okunan veriler, veri değişkenine atanıyor

filtre=veri[(veri['yil']==2018)]

filtre
# Out:
#         plaka  dakika  saat  gun  ay   yil  skod
# 2     43ZL681      38     9   28   4  2018    43
# 3    38PFL195      51    22   13  10  2018    38
# 5     25UH929      12     2   24  10  2018    25
# 6     24CEB59       8    15   11   3  2018    24
# 7      67HA10      54     2   21   5  2018    67
# 10    75USD34      17    15   15   2  2018    75
# 17    28PG524       5    15    2   4  2018    28
# 18   10MHU726      56    22   24   7  2018    10
# 21    64RV417      20     8   21   7  2018    64
# 27     74BC37      32    12    4   4  2018    74
# 35    67TN388      29    17   18  12  2018    67
# 38    57TK758      56     8    7   5  2018    57
# 48    21RK606      59    22   24   5  2018    21
# 50   68KPR937      53    16   16   4  2018    68
# 51    27MZ271      15    15    9  11  2018    27
# 55    34HT824      51    22   12   9  2018    34
# 56    57FZ535      24     5   26   2  2018    57
# 65    46HK609      43    21    6  11  2018    46
# ...

# %% [markdown]
# # 2018 yılında geçen araçların SAYISI

# %%
import pandas as pd

yol='C:\\Users\\mertoglue\\AnacondaProjects\\CSV\\plakaOlustur\\giden.csv'
        
veri = pd.read_csv(yol, encoding = "ISO-8859-1" ,sep=',')   # pandas ile dosya okunup veriler alınıyor ve okunan veriler, veri değişkenine atanıyor

filtre=veri[(veri['yil']==2018)].count()[0]

filtre
# Out:
# 114

# %% [markdown]
# # Herhangi bir yılın Mayıs ayında geçen araçlar

# %%
import pandas as pd

yol='C:\\Users\\mertoglue\\AnacondaProjects\\CSV\\plakaOlustur\\giden.csv'
        
veri = pd.read_csv(yol, encoding = "ISO-8859-1" ,sep=',')   # pandas ile dosya okunup veriler alınıyor ve okunan veriler, veri değişkenine atanıyor

filtre=veri[(veri['ay']==5)]
#filtre=veri[(veri['ay']==5)].count()[0]      # Kaç tane oldukları
filtre
# Out:
# 41

# %% [markdown]
# # İstanbul Plakalı olup gelen araçlar

# %%
import pandas as pd

yol='C:\\Users\\mertoglue\\AnacondaProjects\\CSV\\plakaOlustur\\giden.csv'
        
veri = pd.read_csv(yol, encoding = "ISO-8859-1" ,sep=',')   # pandas ile dosya okunup veriler alınıyor ve okunan veriler, veri değişkenine atanıyor

filtre=veri[(veri['skod']==34)]

filtre
# Out:
#         plaka  dakika  saat  gun  ay   yil  skod
# 44   34GSK470      10    16   12  11  2015    34
# 55    34HT824      51    22   12   9  2018    34
# 103  34RCL491      53    11   20   9  2017    34
# 145   34VS651      38    18    4   6  2016    34
# 188  34TVE395      37     1   26  11  2015    34
# 267   34NE695      19    13   13   8  2018    34
# 304  34DNC249      45    18    6   9  2016    34
# 370   34GZB46       3     7   26  11  2016    34
# 405  34JNA216      14    20   19   9  2018    34
# 468   34AM738      39    15   20   6  2015    34

# %% [markdown]
# # Ankara Plakalı olup gelen araçlar

# %%
import pandas as pd

yol='C:\\Users\\mertoglue\\AnacondaProjects\\CSV\\plakaOlustur\\giden.csv'
        
veri = pd.read_csv(yol, encoding = "ISO-8859-1" ,sep=',')   # pandas ile dosya okunup veriler alınıyor ve okunan veriler, veri değişkenine atanıyor

filtre=veri[(veri['skod']==6)]

filtre
# Out:
#         plaka  dakika  saat  gun  ay   yil  skod
# 82    06IZ536       9    11   13   9  2016     6
# 114   06IL237       3    20    5   7  2017     6
# 246  06PCL720      50     8    5   3  2015     6
# 284   06RO918      47    16   14   1  2016     6

# %% [markdown]
# # 2018 ve öncesinde 5. ayda geçen araçlar

# %%
import pandas as pd

yol='C:\\Users\\mertoglue\\AnacondaProjects\\CSV\\plakaOlustur\\giden.csv'
        
veri = pd.read_csv(yol, encoding = "ISO-8859-1" ,sep=',')   # pandas ile dosya okunup veriler alınıyor ve okunan veriler, veri değişkenine atanıyor

filtre=veri[(veri['yil']<=2018) & (veri['ay']==5)]

filtre
# Out:
#         plaka  dakika  saat  gun  ay   yil  skod
# 7      67HA10      54     2   21   5  2018    67
# 38    57TK758      56     8    7   5  2018    57
# 48    21RK606      59    22   24   5  2018    21
# 57    38FG461      14    22   11   5  2016    38
# 81    53YH401      29    15   19   5  2015    53
# 84    61OT545      35     6   20   5  2018    61
# 101   39GB315      22    13    1   5  2017    39
# 106   51RB128      60     7   22   5  2015    51
# 113  55GVD334      50    19    8   5  2015    55
# 120   54GI940       8    18    8   5  2018    54
# 122  31GML173      37    20   15   5  2016    31
# 124  35SRF840      21     2   13   5  2015    35
# 127  44ITF870       6    13   26   5  2018    44
# 130   13VAS32      30    13   19   5  2015    13
# 131   47NZ834      46    23   26   5  2016    47
# 154   26LT988      50    11    6   5  2016    26
# 169   23GB964      23    16   20   5  2016    23
# 187  10ADT869       9     1   14   5  2017    10
# ...

# %% [markdown]
# # 2018 ve öncesinde 9. ayda plakası 34 olan(İstanbul ili) geçen araçlar

# %%
import pandas as pd

# yol='C:\\Users\\mertoglue\\AnacondaProjects\\CSV\\analiz\\olustur.csv'
yol='C:\\Users\\mertoglue\\AnacondaProjects\\CSV\\plakaOlustur\\giden.csv'
        
veri = pd.read_csv(yol, encoding = "ISO-8859-1" ,sep=',')   # pandas ile dosya okunup veriler alınıyor ve okunan veriler, veri değişkenine atanıyor

filtre=veri[(veri['yil']<=2018) & (veri['ay']==9) & (veri['skod']==34) ]

filtre
# Out:
#         plaka  dakika  saat  gun  ay   yil  skod
# 55    34HT824      51    22   12   9  2018    34
# 103  34RCL491      53    11   20   9  2017    34
# 304  34DNC249      45    18    6   9  2016    34
# 405  34JNA216      14    20   19   9  2018    34
